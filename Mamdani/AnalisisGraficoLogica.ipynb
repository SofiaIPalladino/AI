# %% [markdown]
# ### A partir de la siguiente gráfica de instanciación de dos variables del antecedente de una regla de inferencia fuzzy (se fijan valores para cada una de ellas):
#
# - Variable: Humedad del suelo → Conjuntos: Baja y Alta
#
# - Variable: Existencia de malezas en el lote → Conjuntos: Escasa y Abundante
#
# - Variable de salida: Horas de riego indicadas → Conjuntos: Pocas y muchas.
#
# - ![image.png](data:image/png;base64,...)
#
# 1. Deduzca las reglas de inferencia.
#
# 2. Deduzca los operadores utilizados en el antecedente de las reglas y en la implicación
#
# 3. Sugiera qué tipo de operación pudo haber sido utilizado en la agregación.

# %% [markdown]
# ---

# %% [markdown]
# 1.
# Reglas de inferencia
# 1. Si la humedad del suelo es baja y la existencia de malezas es escaza entonces las horas de riego seran muchas
#
# 2. Si la humedad del suelo es alta y la existencia de malezas es abundante entonces las horas de riego seran muchas
#
# 3. Si la humedad del suelo es baja y la existencia de malezas es abundante entonces las horas de riego seran pocas
#
# 4. Si la humedad del suelo es alta y la existencia de malezas es escaza entonces las horas de riego seran pocas
#
#
# 2.
#
#       p=humedad del suelo alta
#
#       q=existencia de malezas abundante
#
#       r=muchas horas de riego
#
#         1. (-p) AND (-q) THEN r
#
#         2. p AND q THEN -r
#
#         3. (-p) AND q THEN (-r)
#
#         4. p AND (-q) THEN (-r)
#
#
# 3. Durante la agregación se seleccionará el máximo grado de pertenencia. Si ambas reglas afectan el mismo valor de salida, el valor final para ese punto será el mayor entre los producidos por las reglas activas.
# Entonces el tipo de operacion utilizado pudo haber sido el OR
